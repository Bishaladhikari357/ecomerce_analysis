# %%
import numpy as np;
import pandas as pd;
import seaborn as sns;
import matplotlib.pyplot as plt;
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("heart_disease_dataset.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   62   M           ASY        182          251          1         ST    131
# 1   48   F           ATA        185          276          0        LVH    139
# 2   39   F           ASY        147          325          0        LVH    115
# 3   78   M           ATA        159          140          0         ST    150
# 4   62   M           ATA        185          190          1     Normal     83
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              Y      0.9     Flat             1
# 1              N      5.5     Down             1
# 2              N      5.0     Flat             1
# 3              Y      0.6     Flat             1
# 4              Y      4.7       Up             1

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='str')

# %%
df.shape
# Out:
# (801, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             801 non-null    int64
#  1   Sex             801 non-null    str
#  2   ChestPainType   801 non-null    str
#  3   RestingBP       801 non-null    int64
#  4   Cholesterol     801 non-null    int64
#  5   FastingBS       801 non-null    int64
#  6   RestingECG      801 non-null    str
#  7   MaxHR           801 non-null    int64
#  8   ExerciseAngina  801 non-null    str
#  9   Oldpeak         801 non-null    float64
#  10  ST_Slope        801 non-null    str
#  11  HeartDisease    801 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 75.2 KB

# %%
# only Numeric Data are display 
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  801.000000  801.000000   801.000000  801.000000  801.000000
# mean    54.186017  140.335830   267.790262    0.490637  128.857678
# std     14.963091   29.411959    85.635571    0.500225   41.986899
# min     28.000000   90.000000   120.000000    0.000000   60.000000
# 25%     42.000000  116.000000   192.000000    0.000000   92.000000
# 50%     54.000000  141.000000   272.000000    0.000000  128.000000
# 75%     67.000000  165.000000   342.000000    1.000000  165.000000
# max     80.000000  190.000000   420.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  801.000000    801.000000
# mean     3.132459      0.882647
# std      1.779437      0.322042
# min      0.000000      0.000000
# 25%      1.700000      1.000000
# 50%      3.100000      1.000000
# 75%      4.700000      1.000000
# max      6.200000      1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    707
# 0     94
# Name: count, dtype: int64

# %%
df['HeartDisease'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
def plotting (var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var],kde = True)

plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)
#if image space collaps each other then remove by using 
plt.tight_layout()
